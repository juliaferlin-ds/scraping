# %%
from selenium import webdriver

# %%
chrome_path = r"C:\Users\Julia Felin\Downloads\chromedriver_win32\chromedriver.exe"

# %%
driver = webdriver.Chrome(chrome_path)

# %%
driver.get("https://www.google.com/maps/place/Bakso+President+Malang/@-7.962415,112.6345443,17z/data=!4m7!3m6!1s0x2dd628335d4e5bfd:0x857ffeffd55450b0!8m2!3d-7.962415!4d112.636733!9m1!1b1")

# %%
posts = driver.find_elements_by_class_name("section-review-text")

# %%
for post in posts:
    print(post.text)
# Out:
# Mantab rasanya
# Harga sepadan
# Nge hits nya ok
# Lokasi unik...persis pinggir rel kereta. Jiadi harap super hati-hati bagi yg mengajak anak kecil.
# Yg disayangkan adalah, klo take away kog gk elit banget ya...cuma diplastik (mirip beli di angkringan/warung kaki lima...gk se level sm harganya)
# Padahal kadang pengen jg beliin u dibawa ke hotel (terutama bakso gorengnya)
# Saran: lebih baik tambah harga dikit, tp kelihatan lebih 'layak' u dibawa...apalagi klo u oleh² teman/saudara
#
# saya beli bakso bakar, mayan enak lah ngobati rasa kangen dan nostalgia dulu. dan tempatnya unik karena menjual moment diamana kita makan bisa melihat kereta api di samping kita saat makan.. hahaha jadi pas deh buat berburu foto unik bareng keluarga atau temen bahkan orang tersayang.. ya antri banget maklum sih karena tempatnya unik, kalok untuk rasa sama aja baksonya enak kayak bakso malang lainya.
#
# Sensasi makan d tmpat ini adalah Krn di pinggir rel kereta api.
# ...

# %%
import pandas as pd

# %%
header = ['reviews']
df = pd.DataFrame(index=range(1,len(posts)), columns=header)
print(df)
# Out:
#      reviews
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 10       NaN
# 11       NaN
# 12       NaN
# 13       NaN
# 14       NaN
# 15       NaN
# 16       NaN
# 17       NaN
# 18       NaN
# 19       NaN
# 20       NaN
# 21       NaN
# 22       NaN
# 23       NaN
# 24       NaN
# 25       NaN
# 26       NaN
# 27       NaN
# 28       NaN
# 29       NaN
# 30       NaN
# ...      ...
# 2606     NaN
# 2607     NaN
# 2608     NaN
# 2609     NaN
# 2610     NaN
# 2611     NaN
# 2612     NaN
# 2613     NaN
# 2614     NaN
# 2615     NaN
# 2616     NaN
# 2617     NaN
# 2618     NaN
# 2619     NaN
# 2620     NaN
# 2621     NaN
# 2622     NaN
# 2623     NaN
# 2624     NaN
# 2625     NaN
# 2626     NaN
# 2627     NaN
# 2628     NaN
# 2629     NaN
# 2630     NaN
# 2631     NaN
# 2632     NaN
# 2633     NaN
# 2634     NaN
# 2635     NaN
#
# [2635 rows x 1 columns]

# %%
i = 0

# %%
for post in posts:
    post = post.text
    post = post.replace('\n', ' ').replace('\n\n','\n')
    df.loc[i] = post
    i+=1
    
df.head()
# Out:
#                                              reviews
# 1
# 2  saya beli bakso bakar, mayan enak lah ngobati ...
# 3
# 4  Sensasi makan d tmpat ini adalah Krn di pinggi...
# 5

# %%
df.to_csv("bissmillah.csv", sep=',',index=False, line_terminator='\n')

# %% [markdown]
# ## Sekarang srapping nama, tanggal hamdallah :))))

# %%
names = driver.find_elements_by_class_name('section-review-title')

# %%
for name in names:
    print(name.text)
# Out:
# Anie nina
#
# David Kristanto
#
# renatha hutapea
#
# Mustika Purnama Cendana Juwita
#
# prisma ambara
#
# PM Santoso
#
# Yusvita Maulidia
#
# Egatama Mohamad
#
# dedi santoso
#
# Rahmat Djajadi
#
# wiwik limianto
#
# Savage Banana
#
# mas emok
#
# Arsan Dwi Hamong Mukti
#
# assd jihan
#
# bayu cahyanto
#
# vie desky
#
# MONEL SHOP MALANG
#
# Oktavia Regina
#
# Ulya Oktaviani
#
# Arief Rachman Hakim
#
# Riskha Febriani Hapsari
#
# ronin2469
#
# Arip Prasetyo
#
# Dimaz Maxima
#
# Eka Sutria
#
# Dwi Nopa
#
# Wahyu Dwi Widayanti
#
# Bhekti Lestari
#
# Fitrah Dwi Wahyu Septian
#
# agatha vitty deviati
#
# diox airx
#
# Enny Mamito
#
# Durroh Fuadin
#
# Robert Prabowo
#
# Nugroho Pahlevi
#
# Lenny Purwati
#
# novi afif
#
# teguh supriyanto
#
# Nurdiyanto
#
# tritya dipakara
#
# Desiandi Sayful
#
# Riska Fitrah Aprianti
#
# Dahniar Herdiani
#
# Wiranata agil
#
# Arif Ardiawan
#
# dj
#
# Nugroho Iman Priyono
#
# oh_my piknik
#
# Kurnia Ayuningtias
#
# Annie Khasanah
#
# YULIONO JOE
#
# ...

# %%
header = ['names','reviews']
df = pd.DataFrame(index=range(1,len(names)), columns=header)
print(df)
# Out:
#      names reviews
# 1      NaN     NaN
# 2      NaN     NaN
# 3      NaN     NaN
# 4      NaN     NaN
# 5      NaN     NaN
# 6      NaN     NaN
# 7      NaN     NaN
# 8      NaN     NaN
# 9      NaN     NaN
# 10     NaN     NaN
# 11     NaN     NaN
# 12     NaN     NaN
# 13     NaN     NaN
# 14     NaN     NaN
# 15     NaN     NaN
# 16     NaN     NaN
# 17     NaN     NaN
# 18     NaN     NaN
# 19     NaN     NaN
# 20     NaN     NaN
# 21     NaN     NaN
# 22     NaN     NaN
# 23     NaN     NaN
# 24     NaN     NaN
# 25     NaN     NaN
# 26     NaN     NaN
# 27     NaN     NaN
# 28     NaN     NaN
# 29     NaN     NaN
# 30     NaN     NaN
# ...    ...     ...
# 2606   NaN     NaN
# 2607   NaN     NaN
# 2608   NaN     NaN
# 2609   NaN     NaN
# 2610   NaN     NaN
# 2611   NaN     NaN
# 2612   NaN     NaN
# 2613   NaN     NaN
# 2614   NaN     NaN
# 2615   NaN     NaN
# 2616   NaN     NaN
# 2617   NaN     NaN
# 2618   NaN     NaN
# 2619   NaN     NaN
# 2620   NaN     NaN
# ...

# %%
i = 0
for name, post in zip(names,posts):
    name = name.text
    name = name.replace('\n\n','\n')
    post = post.text
    post = post.replace('\n', ' ').replace('\n\n','\n')
    df.loc[i] = [name,post]
    i+=1
    
df.head()
# Out:
#              names                                            reviews
# 1
# 2  David Kristanto  saya beli bakso bakar, mayan enak lah ngobati ...
# 3
# 4  renatha hutapea  Sensasi makan d tmpat ini adalah Krn di pinggi...
# 5

# %%
df.to_csv("youcandoit.csv", sep=',',index=False, line_terminator='\n')
